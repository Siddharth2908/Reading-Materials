# %%
import os
import pandas as pandas
os.chdir("C:/Siddhartha")
IAV = pandas.read_csv("IAV Analysis Raw File.csv")
IAV_output = pandas.DataFrame(IAV.groupby(["Team","Role for IAV"]).describe())
IAV_output.to_csv("IAV Output.csv")

# %%
IAV
# Out:
#      Bank ID              Employee Name     Unit                  Team  \
# 0    1578812           A,Sundaravadivel  Lending  Customer Origination
# 1    1571993                  K,Asharaf  Lending  Customer Origination
# 2    1570287                S,Surendran  Lending  Customer Origination
# 3    1567691            V,Benazeer banu  Lending  Customer Origination
# 4    1565117                 R C,Ramani  Lending  Customer Origination
# 5    1563965                    S,Jeeva  Lending  Customer Origination
# 6    1560928                    M,Latha  Lending  Customer Origination
# 7    1558468                 P,Iswariya  Lending  Customer Origination
# 8    1554917                   G,Kamali  Lending  Customer Origination
# 9    1536956                  M,Rathesh  Lending  Customer Origination
# 10   1535085                  V,Vincent  Lending  Customer Origination
# 11   1534200            N,Karthigeswari  Lending  Customer Origination
# ...
